# %% [markdown]
# # LeanCoder Tutorial: Baseline Evaluation
#
# This notebook demonstrates how to run a baseline evaluation on a base model.

# %%
import sys
sys.path.insert(0, '../src')

from eval.benchmarks import BenchmarkSuite
from eval.sandbox import DockerSandbox
from config import config

# %% [markdown]
# ## Initialize Benchmark Suite

# %%
# Create benchmark suite
suite = BenchmarkSuite()
print(f"Loaded {len(suite)} benchmark suites")

# %% [markdown]
# ## Load Base Model

# %%
# Placeholder: Load base model
# In real usage, this would load the actual model
model = None
print("Model loaded (placeholder)")

# %% [markdown]
# ## Run HumanEval Benchmark

# %%
# Run HumanEval benchmark
results = suite.run_benchmark("humaneval", model, n_samples=10)

print(f"Pass@1: {results.pass_at_1:.2%}")
print(f"Pass@10: {results.pass_at_10:.2%}")
print(f"Total problems: {results.total_problems}")

# %% [markdown]
# ## Run All Benchmarks

# %%
# Run all benchmarks
all_results = suite.run_all_benchmarks(model, n_samples=10)

# Get summary
summary = suite.get_summary(all_results)
print(f"Overall Pass Rate: {summary['overall_pass_rate']:.2%}")

# %% [markdown]
# ## Summary
#
# This notebook demonstrated:
# 1. Loading benchmark suites
# 2. Running individual benchmarks
# 3. Running all benchmarks
# 4. Analyzing results
#
# Next steps: Try the fine-tuning notebook to improve on this baseline!
